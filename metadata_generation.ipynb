# %% [markdown]
# <a href="https://colab.research.google.com/github/AndyCraig200/workout-api/blob/main/metadata_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Google Collab Stuff
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
!

# %%
# !pip install ultralytics #To install model in collab
from ultralytics import YOLO
from ultralytics.solutions import ai_gym
import cv2
from PIL import Image
import os
import numpy as np
import re
import pandas as pd

model = YOLO("yolov8n-pose.pt")
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.1.27-py3-none-any.whl (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.2/721.2 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.17.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 28.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 42.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 35.6 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.5 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.7 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.4 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 6.8 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.6 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.5 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 55.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, thop, ultralytics
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 thop-0.1.1.post2209072238 ultralytics-8.1.27
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8n-pose.pt to 'yolov8n-pose.pt'...
# 100%|██████████| 6.51M/6.51M [00:00<00:00, 84.7MB/s]

# %%
LEFT_ELBOW_PTS = [5, 7, 9]
RIGHT_ELBOW_PTS = [6, 8, 10]
LEFT_SHOULDER_PTS = [7, 5, 11]
RIGHT_SHOULDER_PTS = [8, 6, 12]
LEFT_HIP_PTS = [5, 11, 13]
RIGHT_HIP_PTS = [6, 12, 14]
LEFT_KNEE_PTS = [11, 13, 15]
RIGHT_KNEE_PTS = [12, 14, 16]
angle_indices = [
    LEFT_ELBOW_PTS,
    RIGHT_ELBOW_PTS,
    LEFT_SHOULDER_PTS,
    RIGHT_SHOULDER_PTS,
    LEFT_HIP_PTS,
    RIGHT_HIP_PTS,
    LEFT_KNEE_PTS,
    RIGHT_KNEE_PTS
]
def estimate_pose_angle(a, b, c):
    a, b, c = np.array(a), np.array(b), np.array(c)
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    if angle > 180.0:
        angle = 360 - angle
    return angle

def calculate_angles(indices, keypoints):
    for ind, k in enumerate(reversed(keypoints)):
      angles = []
      for idx_set in indices:
            p1, p2, p3 = [k[idx] for idx in idx_set]
            angle = estimate_pose_angle(p1, p2, p3)
            angles.append(angle)
      return angles

def separate_string(input_string):
    # Define the regex pattern to extract video, frame, and id
    pattern = r'(\w+)-(\d+)_jpg\.rf\.(\w+)\.jpg'

    # Match the pattern against the input string
    match = re.match(pattern, input_string)

    if match:
        # Extract video, frame, and id from the matched groups
        video = match.group(1)
        frame = match.group(2)
        id = match.group(3)


    else:
        video = "null"
          # Extracting frame number
        frame_match = re.search(r'mov-(\d+)', input_string)
        if frame_match:
            frame = frame_match.group(1)
        else:
            frame = None

        # Extracting ID
        id_match = re.search(r'rf\.([a-f0-9]+)\.jpg', input_string)
        if id_match:
            id = id_match.group(1)
        else:
            id = None

    return video, frame, id

def generate_metadata_csv(classes, dataset_path, metadata_path):
    # Check if the provided path is a directory
    if not os.path.isdir(dataset_path):
        print(f"{dataset_path} is not a valid directory.")
        return
    metadata=[]
    for class_folder in classes:
        class_path = f'{dataset_path}/{class_folder}'
        files = os.listdir(class_path)
        count = 0
        for file_name in files:
            count+=1
            print(f'Processing file {count}/{len(files)} in {class_folder}')
            try:
                video, frame, id = separate_string(file_name)
                img = Image.open(class_path + '/' + file_name)
                results = model.predict(img, verbose=False)
                keypoints = results[0].keypoints.data
                angles = calculate_angles(angle_indices, keypoints)
                metadata.append([video, frame, id, class_folder] + angles)
            except Exception as e:
                # handle other exceptions
                print(f'An error occurred when processing file: {file_name}')

    column_names = ['Video', 'Frame', 'ID','Exercise', 'Left Elbow Angle', 'Right Elbow Angle', 'Left Shoulder Angle', 'Right Shoulder Angle', 'Left Hip Angle', 'Right Hip Angle', 'Left Knee Angle', 'Right Knee Angle']
    df = pd.DataFrame(metadata, columns=column_names)
   # Write DataFrame to CSV file
    df.to_csv(metadata_path, index=False)
def calculate_rebased_keypoints(key_points, bounding_box):
    x1, y1, x2, y2 = bounding_box
    box_width = x2 - x1
    box_height = y2 - y1
    data = [box_width, box_height]

    for kp in key_points:
        x_norm, y_norm = kp
        x_rebased_n = ((x_norm - x1) / box_width)
        y_rebased_n = ((y_norm - y1) / box_height)
        data.extend([x_rebased_n, y_rebased_n])
    return data
def generate_keypoints_metadata_csv(classes, dataset_path, metadata_path):
    # Check if the provided path is a directory
    if not os.path.isdir(dataset_path):
        print(f"{dataset_path} is not a valid directory.")
        return
    metadata=[]
    for class_folder in classes:
        class_path = f'{dataset_path}/{class_folder}'
        files = os.listdir(class_path)
        count = 0
        for file_name in files:
            count+=1
            print(f'Processing file {count}/{len(files)} in {class_folder}')
            try:
                video, frame, id = separate_string(file_name)
                img = Image.open(class_path + '/' + file_name)
                results = model.predict(img, verbose=False)
                row = calculate_rebased_keypoints(key_points=results[0].keypoints.xyn.numpy()[0],
                                          bounding_box=results[0].boxes.xyxyn.numpy()[0])
                metadata.append([video, frame, id, class_folder] + row)
            except Exception as e:
                # handle other exceptions
                print(f'An error occurred when processing file: {file_name}')

    columns = ['Video', 'Frame', 'ID','Exercise','box_width', 'box_height']
    for i in range(17):
        columns.append(f'kp_{i+1}_x')
        columns.append(f'kp_{i+1}_y')
    df = pd.DataFrame(metadata, columns=columns)
   # Write DataFrame to CSV file
    df.to_csv(metadata_path, index=False)

# %%
# Set'folder_path' to the actual path of the folder you want to analyze
classes = ["Deadlift", "Pushup", "Squat", "Other"]
output_path = "/content/drive/MyDrive/capstone/dataset_v2/metadata/metadata_kp_train_v1.csv"
dataset_path = '/content/drive/MyDrive/capstone/dataset_v2/labelling/train/'
generate_keypoints_metadata_csv(classes, dataset_path, output_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing file 991/2633 in Pushup
# Processing file 992/2633 in Pushup
# Processing file 993/2633 in Pushup
# Processing file 994/2633 in Pushup
# Processing file 995/2633 in Pushup
# Processing file 996/2633 in Pushup
# Processing file 997/2633 in Pushup
# Processing file 998/2633 in Pushup
# Processing file 999/2633 in Pushup
# Processing file 1000/2633 in Pushup
# Processing file 1001/2633 in Pushup
# Processing file 1002/2633 in Pushup
# Processing file 1003/2633 in Pushup
# Processing file 1004/2633 in Pushup
# Processing file 1005/2633 in Pushup
# Processing file 1006/2633 in Pushup
# Processing file 1007/2633 in Pushup
# Processing file 1008/2633 in Pushup
# Processing file 1009/2633 in Pushup
# Processing file 1010/2633 in Pushup
# Processing file 1011/2633 in Pushup
# Processing file 1012/2633 in Pushup
# Processing file 1013/2633 in Pushup
# Processing file 1014/2633 in Pushup
# Processing file 1015/2633 in Pushup
# Processing file 1016/2633 in Pushup
# Processing file 1017/2633 in Pushup
# Processing file 1018/2633 in Pushup
# Processing file 1019/2633 in Pushup
# Processing file 1020/2633 in Pushup
# Processing file 1021/2633 in Pushup
# Processing file 1022/2633 in Pushup
# Processing file 1023/2633 in Pushup
# Processing file 1024/2633 in Pushup
# Processing file 1025/2633 in Pushup
# Processing file 1026/2633 in Pushup
# Processing file 1027/2633 in Pushup
# Processing file 1028/2633 in Pushup
# Processing file 1029/2633 in Pushup
# Processing file 1030/2633 in Pushup
# Processing file 1031/2633 in Pushup
# Processing file 1032/2633 in Pushup
# Processing file 1033/2633 in Pushup
# Processing file 1034/2633 in Pushup
# Processing file 1035/2633 in Pushup
# Processing file 1036/2633 in Pushup
# Processing file 1037/2633 in Pushup
# Processing file 1038/2633 in Pushup
# Processing file 1039/2633 in Pushup
# Processing file 1040/2633 in Pushup
# Processing file 1041/2633 in Pushup
# Processing file 1042/2633 in Pushup
# Processing file 1043/2633 in Pushup
# Processing file 1044/2633 in Pushup
# Processing file 1045/2633 in Pushup
# Processing file 1046/2633 in Pushup
# Processing file 1047/2633 in Pushup
# Processing file 1048/2633 in Pushup
# Processing file 1049/2633 in Pushup
# Processing file 1050/2633 in Pushup
# Processing file 1051/2633 in Pushup
# Processing file 1052/2633 in Pushup
# Processing file 1053/2633 in Pushup
# Processing file 1054/2633 in Pushup
# Processing file 1055/2633 in Pushup
# Processing file 1056/2633 in Pushup
# Processing file 1057/2633 in Pushup
# Processing file 1058/2633 in Pushup
# Processing file 1059/2633 in Pushup
# Processing file 1060/2633 in Pushup
# Processing file 1061/2633 in Pushup
# Processing file 1062/2633 in Pushup
# Processing file 1063/2633 in Pushup
# Processing file 1064/2633 in Pushup
# Processing file 1065/2633 in Pushup
# Processing file 1066/2633 in Pushup
# Processing file 1067/2633 in Pushup
# Processing file 1068/2633 in Pushup
# Processing file 1069/2633 in Pushup
# Processing file 1070/2633 in Pushup
# Processing file 1071/2633 in Pushup
# Processing file 1072/2633 in Pushup
# Processing file 1073/2633 in Pushup
# Processing file 1074/2633 in Pushup
# Processing file 1075/2633 in Pushup
# Processing file 1076/2633 in Pushup
# Processing file 1077/2633 in Pushup
# Processing file 1078/2633 in Pushup
# Processing file 1079/2633 in Pushup
# Processing file 1080/2633 in Pushup
# Processing file 1081/2633 in Pushup
# Processing file 1082/2633 in Pushup
# Processing file 1083/2633 in Pushup
# Processing file 1084/2633 in Pushup
# Processing file 1085/2633 in Pushup
# Processing file 1086/2633 in Pushup
# Processing file 1087/2633 in Pushup
# Processing file 1088/2633 in Pushup
# Processing file 1089/2633 in Pushup
# Processing file 1090/2633 in Pushup
# Processing file 1091/2633 in Pushup
# Processing file 1092/2633 in Pushup
# Processing file 1093/2633 in Pushup
# Processing file 1094/2633 in Pushup
# Processing file 1095/2633 in Pushup
# Processing file 1096/2633 in Pushup
# Processing file 1097/2633 in Pushup
# Processing file 1098/2633 in Pushup
# Processing file 1099/2633 in Pushup
# Processing file 1100/2633 in Pushup
# Processing file 1101/2633 in Pushup
# Processing file 1102/2633 in Pushup
# Processing file 1103/2633 in Pushup
# Processing file 1104/2633 in Pushup
# Processing file 1105/2633 in Pushup
# Processing file 1106/2633 in Pushup
# Processing file 1107/2633 in Pushup
# Processing file 1108/2633 in Pushup
# Processing file 1109/2633 in Pushup
# Processing file 1110/2633 in Pushup
# Processing file 1111/2633 in Pushup
# Processing file 1112/2633 in Pushup
# Processing file 1113/2633 in Pushup
# Processing file 1114/2633 in Pushup
# Processing file 1115/2633 in Pushup
# Processing file 1116/2633 in Pushup
# Processing file 1117/2633 in Pushup
# Processing file 1118/2633 in Pushup
# Processing file 1119/2633 in Pushup
# Processing file 1120/2633 in Pushup
# Processing file 1121/2633 in Pushup
# Processing file 1122/2633 in Pushup
# Processing file 1123/2633 in Pushup
# Processing file 1124/2633 in Pushup
# Processing file 1125/2633 in Pushup
# Processing file 1126/2633 in Pushup
# Processing file 1127/2633 in Pushup
# Processing file 1128/2633 in Pushup
# Processing file 1129/2633 in Pushup
# Processing file 1130/2633 in Pushup
# Processing file 1131/2633 in Pushup
# Processing file 1132/2633 in Pushup
# Processing file 1133/2633 in Pushup
# Processing file 1134/2633 in Pushup
# Processing file 1135/2633 in Pushup
# Processing file 1136/2633 in Pushup
# Processing file 1137/2633 in Pushup
# Processing file 1138/2633 in Pushup
# Processing file 1139/2633 in Pushup
# Processing file 1140/2633 in Pushup
# Processing file 1141/2633 in Pushup
# Processing file 1142/2633 in Pushup
# Processing file 1143/2633 in Pushup
# Processing file 1144/2633 in Pushup
# Processing file 1145/2633 in Pushup
# Processing file 1146/2633 in Pushup
# Processing file 1147/2633 in Pushup
# Processing file 1148/2633 in Pushup
# Processing file 1149/2633 in Pushup
# Processing file 1150/2633 in Pushup
# Processing file 1151/2633 in Pushup
# Processing file 1152/2633 in Pushup
# Processing file 1153/2633 in Pushup
# Processing file 1154/2633 in Pushup
# Processing file 1155/2633 in Pushup
# Processing file 1156/2633 in Pushup
# Processing file 1157/2633 in Pushup
# Processing file 1158/2633 in Pushup
# Processing file 1159/2633 in Pushup
# Processing file 1160/2633 in Pushup
# Processing file 1161/2633 in Pushup
# Processing file 1162/2633 in Pushup
# Processing file 1163/2633 in Pushup
# Processing file 1164/2633 in Pushup
# Processing file 1165/2633 in Pushup
# Processing file 1166/2633 in Pushup
# Processing file 1167/2633 in Pushup
# Processing file 1168/2633 in Pushup
# Processing file 1169/2633 in Pushup
# Processing file 1170/2633 in Pushup
# Processing file 1171/2633 in Pushup
# Processing file 1172/2633 in Pushup
# Processing file 1173/2633 in Pushup
# Processing file 1174/2633 in Pushup
# Processing file 1175/2633 in Pushup
# Processing file 1176/2633 in Pushup
# Processing file 1177/2633 in Pushup
# Processing file 1178/2633 in Pushup
# Processing file 1179/2633 in Pushup
# Processing file 1180/2633 in Pushup
# Processing file 1181/2633 in Pushup
# Processing file 1182/2633 in Pushup
# Processing file 1183/2633 in Pushup
# Processing file 1184/2633 in Pushup
# Processing file 1185/2633 in Pushup
# Processing file 1186/2633 in Pushup
# Processing file 1187/2633 in Pushup
# Processing file 1188/2633 in Pushup
# Processing file 1189/2633 in Pushup
# Processing file 1190/2633 in Pushup
# Processing file 1191/2633 in Pushup
# Processing file 1192/2633 in Pushup
# Processing file 1193/2633 in Pushup
# Processing file 1194/2633 in Pushup
# Processing file 1195/2633 in Pushup
# Processing file 1196/2633 in Pushup
# Processing file 1197/2633 in Pushup
# Processing file 1198/2633 in Pushup
# Processing file 1199/2633 in Pushup
# Processing file 1200/2633 in Pushup
# Processing file 1201/2633 in Pushup
# Processing file 1202/2633 in Pushup
# Processing file 1203/2633 in Pushup
# Processing file 1204/2633 in Pushup
# Processing file 1205/2633 in Pushup
# Processing file 1206/2633 in Pushup
# Processing file 1207/2633 in Pushup
# Processing file 1208/2633 in Pushup
# Processing file 1209/2633 in Pushup
# Processing file 1210/2633 in Pushup
# Processing file 1211/2633 in Pushup
# Processing file 1212/2633 in Pushup
# Processing file 1213/2633 in Pushup
# Processing file 1214/2633 in Pushup
# Processing file 1215/2633 in Pushup
# Processing file 1216/2633 in Pushup
# Processing file 1217/2633 in Pushup
# Processing file 1218/2633 in Pushup
# Processing file 1219/2633 in Pushup
# Processing file 1220/2633 in Pushup
# Processing file 1221/2633 in Pushup
# Processing file 1222/2633 in Pushup
# Processing file 1223/2633 in Pushup
# Processing file 1224/2633 in Pushup
# Processing file 1225/2633 in Pushup
# Processing file 1226/2633 in Pushup
# Processing file 1227/2633 in Pushup
# Processing file 1228/2633 in Pushup
# Processing file 1229/2633 in Pushup
# Processing file 1230/2633 in Pushup
# Processing file 1231/2633 in Pushup
# Processing file 1232/2633 in Pushup
# Processing file 1233/2633 in Pushup
# Processing file 1234/2633 in Pushup
# Processing file 1235/2633 in Pushup
# Processing file 1236/2633 in Pushup
# Processing file 1237/2633 in Pushup
# Processing file 1238/2633 in Pushup
# Processing file 1239/2633 in Pushup
# Processing file 1240/2633 in Pushup
# Processing file 1241/2633 in Pushup
# Processing file 1242/2633 in Pushup
# Processing file 1243/2633 in Pushup
# Processing file 1244/2633 in Pushup
# Processing file 1245/2633 in Pushup
# Processing file 1246/2633 in Pushup
# Processing file 1247/2633 in Pushup
# Processing file 1248/2633 in Pushup
# Processing file 1249/2633 in Pushup
# Processing file 1250/2633 in Pushup
# Processing file 1251/2633 in Pushup
# Processing file 1252/2633 in Pushup
# Processing file 1253/2633 in Pushup
# Processing file 1254/2633 in Pushup
# Processing file 1255/2633 in Pushup
# Processing file 1256/2633 in Pushup
# Processing file 1257/2633 in Pushup
# Processing file 1258/2633 in Pushup
# Processing file 1259/2633 in Pushup
# Processing file 1260/2633 in Pushup
# Processing file 1261/2633 in Pushup
# Processing file 1262/2633 in Pushup
# Processing file 1263/2633 in Pushup
# Processing file 1264/2633 in Pushup
# Processing file 1265/2633 in Pushup
# Processing file 1266/2633 in Pushup
# Processing file 1267/2633 in Pushup
# Processing file 1268/2633 in Pushup
# Processing file 1269/2633 in Pushup
# Processing file 1270/2633 in Pushup
# Processing file 1271/2633 in Pushup
# Processing file 1272/2633 in Pushup
# Processing file 1273/2633 in Pushup
# Processing file 1274/2633 in Pushup
# Processing file 1275/2633 in Pushup
# Processing file 1276/2633 in Pushup
# Processing file 1277/2633 in Pushup
# Processing file 1278/2633 in Pushup
# Processing file 1279/2633 in Pushup
# Processing file 1280/2633 in Pushup
# Processing file 1281/2633 in Pushup
# Processing file 1282/2633 in Pushup
# Processing file 1283/2633 in Pushup
# Processing file 1284/2633 in Pushup
# Processing file 1285/2633 in Pushup
# Processing file 1286/2633 in Pushup
# Processing file 1287/2633 in Pushup
# Processing file 1288/2633 in Pushup
# Processing file 1289/2633 in Pushup
# Processing file 1290/2633 in Pushup
# Processing file 1291/2633 in Pushup
# Processing file 1292/2633 in Pushup
# Processing file 1293/2633 in Pushup
# Processing file 1294/2633 in Pushup
# Processing file 1295/2633 in Pushup
# Processing file 1296/2633 in Pushup
# Processing file 1297/2633 in Pushup
# Processing file 1298/2633 in Pushup
# Processing file 1299/2633 in Pushup
# Processing file 1300/2633 in Pushup
# Processing file 1301/2633 in Pushup
# Processing file 1302/2633 in Pushup
# Processing file 1303/2633 in Pushup
# Processing file 1304/2633 in Pushup
# Processing file 1305/2633 in Pushup
# Processing file 1306/2633 in Pushup
# Processing file 1307/2633 in Pushup
# Processing file 1308/2633 in Pushup
# Processing file 1309/2633 in Pushup
# Processing file 1310/2633 in Pushup
# Processing file 1311/2633 in Pushup
# Processing file 1312/2633 in Pushup
# Processing file 1313/2633 in Pushup
# Processing file 1314/2633 in Pushup
# Processing file 1315/2633 in Pushup
# Processing file 1316/2633 in Pushup
# Processing file 1317/2633 in Pushup
# Processing file 1318/2633 in Pushup
# Processing file 1319/2633 in Pushup
# Processing file 1320/2633 in Pushup
# Processing file 1321/2633 in Pushup
# Processing file 1322/2633 in Pushup
# Processing file 1323/2633 in Pushup
# Processing file 1324/2633 in Pushup
# Processing file 1325/2633 in Pushup
# Processing file 1326/2633 in Pushup
# Processing file 1327/2633 in Pushup
# Processing file 1328/2633 in Pushup
# Processing file 1329/2633 in Pushup
# Processing file 1330/2633 in Pushup
# Processing file 1331/2633 in Pushup
# Processing file 1332/2633 in Pushup
# Processing file 1333/2633 in Pushup
# Processing file 1334/2633 in Pushup
# Processing file 1335/2633 in Pushup
# Processing file 1336/2633 in Pushup
# Processing file 1337/2633 in Pushup
# Processing file 1338/2633 in Pushup
# Processing file 1339/2633 in Pushup
# Processing file 1340/2633 in Pushup
# Processing file 1341/2633 in Pushup
# Processing file 1342/2633 in Pushup
# Processing file 1343/2633 in Pushup
# Processing file 1344/2633 in Pushup
# Processing file 1345/2633 in Pushup
# Processing file 1346/2633 in Pushup
# Processing file 1347/2633 in Pushup
# Processing file 1348/2633 in Pushup
# Processing file 1349/2633 in Pushup
# Processing file 1350/2633 in Pushup
# Processing file 1351/2633 in Pushup
# Processing file 1352/2633 in Pushup
# Processing file 1353/2633 in Pushup
# Processing file 1354/2633 in Pushup
# Processing file 1355/2633 in Pushup
# Processing file 1356/2633 in Pushup
# Processing file 1357/2633 in Pushup
# Processing file 1358/2633 in Pushup
# Processing file 1359/2633 in Pushup
# Processing file 1360/2633 in Pushup
# Processing file 1361/2633 in Pushup
# Processing file 1362/2633 in Pushup
# Processing file 1363/2633 in Pushup
# Processing file 1364/2633 in Pushup
# Processing file 1365/2633 in Pushup
# Processing file 1366/2633 in Pushup
# Processing file 1367/2633 in Pushup
# Processing file 1368/2633 in Pushup
# Processing file 1369/2633 in Pushup
# Processing file 1370/2633 in Pushup
# Processing file 1371/2633 in Pushup
# Processing file 1372/2633 in Pushup
# Processing file 1373/2633 in Pushup
# Processing file 1374/2633 in Pushup
# Processing file 1375/2633 in Pushup
# Processing file 1376/2633 in Pushup
# Processing file 1377/2633 in Pushup
# Processing file 1378/2633 in Pushup
# Processing file 1379/2633 in Pushup
# Processing file 1380/2633 in Pushup
# Processing file 1381/2633 in Pushup
# Processing file 1382/2633 in Pushup
# Processing file 1383/2633 in Pushup
# Processing file 1384/2633 in Pushup
# Processing file 1385/2633 in Pushup
# Processing file 1386/2633 in Pushup
# Processing file 1387/2633 in Pushup
# Processing file 1388/2633 in Pushup
# Processing file 1389/2633 in Pushup
# Processing file 1390/2633 in Pushup
# Processing file 1391/2633 in Pushup
# Processing file 1392/2633 in Pushup
# Processing file 1393/2633 in Pushup
# Processing file 1394/2633 in Pushup
# Processing file 1395/2633 in Pushup
# Processing file 1396/2633 in Pushup
# Processing file 1397/2633 in Pushup
# Processing file 1398/2633 in Pushup
# Processing file 1399/2633 in Pushup
# Processing file 1400/2633 in Pushup
# Processing file 1401/2633 in Pushup
# Processing file 1402/2633 in Pushup
# Processing file 1403/2633 in Pushup
# Processing file 1404/2633 in Pushup
# Processing file 1405/2633 in Pushup
# Processing file 1406/2633 in Pushup
# Processing file 1407/2633 in Pushup
# Processing file 1408/2633 in Pushup
# Processing file 1409/2633 in Pushup
# Processing file 1410/2633 in Pushup
# Processing file 1411/2633 in Pushup
# Processing file 1412/2633 in Pushup
# Processing file 1413/2633 in Pushup
# Processing file 1414/2633 in Pushup
# Processing file 1415/2633 in Pushup
# Processing file 1416/2633 in Pushup
# Processing file 1417/2633 in Pushup
# Processing file 1418/2633 in Pushup
# Processing file 1419/2633 in Pushup
# Processing file 1420/2633 in Pushup
# Processing file 1421/2633 in Pushup
# Processing file 1422/2633 in Pushup
# Processing file 1423/2633 in Pushup
# Processing file 1424/2633 in Pushup
# Processing file 1425/2633 in Pushup
# Processing file 1426/2633 in Pushup
# Processing file 1427/2633 in Pushup
# Processing file 1428/2633 in Pushup
# Processing file 1429/2633 in Pushup
# Processing file 1430/2633 in Pushup
# Processing file 1431/2633 in Pushup
# Processing file 1432/2633 in Pushup
# Processing file 1433/2633 in Pushup
# Processing file 1434/2633 in Pushup
# Processing file 1435/2633 in Pushup
# Processing file 1436/2633 in Pushup
# Processing file 1437/2633 in Pushup
# Processing file 1438/2633 in Pushup
# Processing file 1439/2633 in Pushup
# Processing file 1440/2633 in Pushup
# Processing file 1441/2633 in Pushup
# Processing file 1442/2633 in Pushup
# Processing file 1443/2633 in Pushup
# Processing file 1444/2633 in Pushup
# Processing file 1445/2633 in Pushup
# Processing file 1446/2633 in Pushup
# Processing file 1447/2633 in Pushup
# Processing file 1448/2633 in Pushup
# Processing file 1449/2633 in Pushup
# Processing file 1450/2633 in Pushup
# Processing file 1451/2633 in Pushup
# Processing file 1452/2633 in Pushup
# Processing file 1453/2633 in Pushup
# Processing file 1454/2633 in Pushup
# Processing file 1455/2633 in Pushup
# Processing file 1456/2633 in Pushup
# Processing file 1457/2633 in Pushup
# Processing file 1458/2633 in Pushup
# Processing file 1459/2633 in Pushup
# Processing file 1460/2633 in Pushup
# Processing file 1461/2633 in Pushup
# Processing file 1462/2633 in Pushup
# Processing file 1463/2633 in Pushup
# Processing file 1464/2633 in Pushup
# Processing file 1465/2633 in Pushup
# Processing file 1466/2633 in Pushup
# Processing file 1467/2633 in Pushup
# Processing file 1468/2633 in Pushup
# Processing file 1469/2633 in Pushup
# Processing file 1470/2633 in Pushup
# Processing file 1471/2633 in Pushup
# Processing file 1472/2633 in Pushup
# Processing file 1473/2633 in Pushup
# Processing file 1474/2633 in Pushup
# Processing file 1475/2633 in Pushup
# Processing file 1476/2633 in Pushup
# Processing file 1477/2633 in Pushup
# Processing file 1478/2633 in Pushup
# Processing file 1479/2633 in Pushup
# Processing file 1480/2633 in Pushup
# Processing file 1481/2633 in Pushup
# Processing file 1482/2633 in Pushup
# Processing file 1483/2633 in Pushup
# Processing file 1484/2633 in Pushup
# Processing file 1485/2633 in Pushup
# Processing file 1486/2633 in Pushup
# Processing file 1487/2633 in Pushup
# Processing file 1488/2633 in Pushup
# Processing file 1489/2633 in Pushup
# Processing file 1490/2633 in Pushup
# Processing file 1491/2633 in Pushup
# Processing file 1492/2633 in Pushup
# Processing file 1493/2633 in Pushup
# Processing file 1494/2633 in Pushup
# Processing file 1495/2633 in Pushup
# Processing file 1496/2633 in Pushup
# Processing file 1497/2633 in Pushup
# Processing file 1498/2633 in Pushup
# Processing file 1499/2633 in Pushup
# Processing file 1500/2633 in Pushup
# Processing file 1501/2633 in Pushup
# Processing file 1502/2633 in Pushup
# Processing file 1503/2633 in Pushup
# Processing file 1504/2633 in Pushup
# Processing file 1505/2633 in Pushup
# Processing file 1506/2633 in Pushup
# Processing file 1507/2633 in Pushup
# Processing file 1508/2633 in Pushup
# Processing file 1509/2633 in Pushup
# Processing file 1510/2633 in Pushup
# Processing file 1511/2633 in Pushup
# Processing file 1512/2633 in Pushup
# Processing file 1513/2633 in Pushup
# Processing file 1514/2633 in Pushup
# Processing file 1515/2633 in Pushup
# Processing file 1516/2633 in Pushup
# Processing file 1517/2633 in Pushup
# Processing file 1518/2633 in Pushup
# Processing file 1519/2633 in Pushup
# Processing file 1520/2633 in Pushup
# Processing file 1521/2633 in Pushup
# Processing file 1522/2633 in Pushup
# Processing file 1523/2633 in Pushup
# Processing file 1524/2633 in Pushup
# Processing file 1525/2633 in Pushup
# Processing file 1526/2633 in Pushup
# Processing file 1527/2633 in Pushup
# Processing file 1528/2633 in Pushup
# Processing file 1529/2633 in Pushup
# Processing file 1530/2633 in Pushup
# Processing file 1531/2633 in Pushup
# Processing file 1532/2633 in Pushup
# Processing file 1533/2633 in Pushup
# Processing file 1534/2633 in Pushup
# Processing file 1535/2633 in Pushup
# Processing file 1536/2633 in Pushup
# Processing file 1537/2633 in Pushup
# Processing file 1538/2633 in Pushup
# Processing file 1539/2633 in Pushup
# Processing file 1540/2633 in Pushup
# Processing file 1541/2633 in Pushup
# Processing file 1542/2633 in Pushup
# Processing file 1543/2633 in Pushup
# Processing file 1544/2633 in Pushup
# Processing file 1545/2633 in Pushup
# Processing file 1546/2633 in Pushup
# Processing file 1547/2633 in Pushup
# Processing file 1548/2633 in Pushup
# Processing file 1549/2633 in Pushup
# Processing file 1550/2633 in Pushup
# Processing file 1551/2633 in Pushup
# Processing file 1552/2633 in Pushup
# Processing file 1553/2633 in Pushup
# Processing file 1554/2633 in Pushup
# Processing file 1555/2633 in Pushup
# Processing file 1556/2633 in Pushup
# Processing file 1557/2633 in Pushup
# Processing file 1558/2633 in Pushup
# Processing file 1559/2633 in Pushup
# Processing file 1560/2633 in Pushup
# Processing file 1561/2633 in Pushup
# Processing file 1562/2633 in Pushup
# Processing file 1563/2633 in Pushup
# Processing file 1564/2633 in Pushup
# Processing file 1565/2633 in Pushup
# Processing file 1566/2633 in Pushup
# Processing file 1567/2633 in Pushup
# Processing file 1568/2633 in Pushup
# Processing file 1569/2633 in Pushup
# Processing file 1570/2633 in Pushup
# Processing file 1571/2633 in Pushup
# Processing file 1572/2633 in Pushup
# Processing file 1573/2633 in Pushup
# Processing file 1574/2633 in Pushup
# Processing file 1575/2633 in Pushup
# Processing file 1576/2633 in Pushup
# Processing file 1577/2633 in Pushup
# Processing file 1578/2633 in Pushup
# Processing file 1579/2633 in Pushup
# Processing file 1580/2633 in Pushup
# Processing file 1581/2633 in Pushup
# Processing file 1582/2633 in Pushup
# Processing file 1583/2633 in Pushup
# Processing file 1584/2633 in Pushup
# Processing file 1585/2633 in Pushup
# Processing file 1586/2633 in Pushup
# Processing file 1587/2633 in Pushup
# Processing file 1588/2633 in Pushup
# Processing file 1589/2633 in Pushup
# Processing file 1590/2633 in Pushup
# Processing file 1591/2633 in Pushup
# Processing file 1592/2633 in Pushup
# Processing file 1593/2633 in Pushup
# Processing file 1594/2633 in Pushup
# Processing file 1595/2633 in Pushup
# Processing file 1596/2633 in Pushup
# Processing file 1597/2633 in Pushup
# Processing file 1598/2633 in Pushup
# Processing file 1599/2633 in Pushup
# Processing file 1600/2633 in Pushup
# Processing file 1601/2633 in Pushup
# Processing file 1602/2633 in Pushup
# Processing file 1603/2633 in Pushup
# Processing file 1604/2633 in Pushup
# Processing file 1605/2633 in Pushup
# Processing file 1606/2633 in Pushup
# Processing file 1607/2633 in Pushup
# Processing file 1608/2633 in Pushup
# Processing file 1609/2633 in Pushup
# Processing file 1610/2633 in Pushup
# Processing file 1611/2633 in Pushup
# Processing file 1612/2633 in Pushup
# Processing file 1613/2633 in Pushup
# Processing file 1614/2633 in Pushup
# Processing file 1615/2633 in Pushup
# Processing file 1616/2633 in Pushup
# Processing file 1617/2633 in Pushup
# Processing file 1618/2633 in Pushup
# Processing file 1619/2633 in Pushup
# Processing file 1620/2633 in Pushup
# Processing file 1621/2633 in Pushup
# Processing file 1622/2633 in Pushup
# Processing file 1623/2633 in Pushup
# Processing file 1624/2633 in Pushup
# Processing file 1625/2633 in Pushup
# Processing file 1626/2633 in Pushup
# Processing file 1627/2633 in Pushup
# Processing file 1628/2633 in Pushup
# Processing file 1629/2633 in Pushup
# Processing file 1630/2633 in Pushup
# Processing file 1631/2633 in Pushup
# Processing file 1632/2633 in Pushup
# Processing file 1633/2633 in Pushup
# Processing file 1634/2633 in Pushup
# Processing file 1635/2633 in Pushup
# Processing file 1636/2633 in Pushup
# Processing file 1637/2633 in Pushup
# Processing file 1638/2633 in Pushup
# Processing file 1639/2633 in Pushup
# Processing file 1640/2633 in Pushup
# Processing file 1641/2633 in Pushup
# Processing file 1642/2633 in Pushup
# Processing file 1643/2633 in Pushup
# Processing file 1644/2633 in Pushup
# Processing file 1645/2633 in Pushup
# Processing file 1646/2633 in Pushup
# Processing file 1647/2633 in Pushup
# Processing file 1648/2633 in Pushup
# Processing file 1649/2633 in Pushup
# Processing file 1650/2633 in Pushup
# Processing file 1651/2633 in Pushup
# Processing file 1652/2633 in Pushup
# Processing file 1653/2633 in Pushup
# Processing file 1654/2633 in Pushup
# Processing file 1655/2633 in Pushup
# Processing file 1656/2633 in Pushup
# Processing file 1657/2633 in Pushup
# Processing file 1658/2633 in Pushup
# Processing file 1659/2633 in Pushup
# Processing file 1660/2633 in Pushup
# Processing file 1661/2633 in Pushup
# Processing file 1662/2633 in Pushup
# Processing file 1663/2633 in Pushup
# Processing file 1664/2633 in Pushup
# Processing file 1665/2633 in Pushup
# Processing file 1666/2633 in Pushup
# Processing file 1667/2633 in Pushup
# Processing file 1668/2633 in Pushup
# Processing file 1669/2633 in Pushup
# Processing file 1670/2633 in Pushup
# Processing file 1671/2633 in Pushup
# Processing file 1672/2633 in Pushup
# Processing file 1673/2633 in Pushup
# Processing file 1674/2633 in Pushup
# Processing file 1675/2633 in Pushup
# Processing file 1676/2633 in Pushup
# Processing file 1677/2633 in Pushup
# Processing file 1678/2633 in Pushup
# Processing file 1679/2633 in Pushup
# Processing file 1680/2633 in Pushup
# Processing file 1681/2633 in Pushup
# Processing file 1682/2633 in Pushup
# Processing file 1683/2633 in Pushup
# Processing file 1684/2633 in Pushup
# Processing file 1685/2633 in Pushup
# Processing file 1686/2633 in Pushup
# Processing file 1687/2633 in Pushup
# Processing file 1688/2633 in Pushup
# Processing file 1689/2633 in Pushup
# Processing file 1690/2633 in Pushup
# Processing file 1691/2633 in Pushup
# Processing file 1692/2633 in Pushup
# Processing file 1693/2633 in Pushup
# Processing file 1694/2633 in Pushup
# Processing file 1695/2633 in Pushup
# Processing file 1696/2633 in Pushup
# Processing file 1697/2633 in Pushup
# Processing file 1698/2633 in Pushup
# Processing file 1699/2633 in Pushup
# Processing file 1700/2633 in Pushup
# Processing file 1701/2633 in Pushup
# Processing file 1702/2633 in Pushup
# Processing file 1703/2633 in Pushup
# Processing file 1704/2633 in Pushup
# Processing file 1705/2633 in Pushup
# Processing file 1706/2633 in Pushup
# Processing file 1707/2633 in Pushup
# Processing file 1708/2633 in Pushup
# Processing file 1709/2633 in Pushup
# Processing file 1710/2633 in Pushup
# Processing file 1711/2633 in Pushup
# Processing file 1712/2633 in Pushup
# Processing file 1713/2633 in Pushup
# Processing file 1714/2633 in Pushup
# Processing file 1715/2633 in Pushup
# Processing file 1716/2633 in Pushup
# Processing file 1717/2633 in Pushup
# Processing file 1718/2633 in Pushup
# Processing file 1719/2633 in Pushup
# Processing file 1720/2633 in Pushup
# Processing file 1721/2633 in Pushup
# Processing file 1722/2633 in Pushup
# Processing file 1723/2633 in Pushup
# Processing file 1724/2633 in Pushup
# Processing file 1725/2633 in Pushup
# Processing file 1726/2633 in Pushup
# Processing file 1727/2633 in Pushup
# Processing file 1728/2633 in Pushup
# Processing file 1729/2633 in Pushup
# Processing file 1730/2633 in Pushup
# Processing file 1731/2633 in Pushup
# Processing file 1732/2633 in Pushup
# Processing file 1733/2633 in Pushup
# Processing file 1734/2633 in Pushup
# Processing file 1735/2633 in Pushup
# Processing file 1736/2633 in Pushup
# Processing file 1737/2633 in Pushup
# Processing file 1738/2633 in Pushup
# Processing file 1739/2633 in Pushup
# Processing file 1740/2633 in Pushup
# Processing file 1741/2633 in Pushup
# Processing file 1742/2633 in Pushup
# Processing file 1743/2633 in Pushup
# Processing file 1744/2633 in Pushup
# Processing file 1745/2633 in Pushup
# Processing file 1746/2633 in Pushup
# Processing file 1747/2633 in Pushup
# Processing file 1748/2633 in Pushup
# Processing file 1749/2633 in Pushup
# Processing file 1750/2633 in Pushup
# Processing file 1751/2633 in Pushup
# Processing file 1752/2633 in Pushup
# Processing file 1753/2633 in Pushup
# Processing file 1754/2633 in Pushup
# Processing file 1755/2633 in Pushup
# Processing file 1756/2633 in Pushup
# Processing file 1757/2633 in Pushup
# Processing file 1758/2633 in Pushup
# Processing file 1759/2633 in Pushup
# Processing file 1760/2633 in Pushup
# Processing file 1761/2633 in Pushup
# Processing file 1762/2633 in Pushup
# Processing file 1763/2633 in Pushup
# Processing file 1764/2633 in Pushup
# Processing file 1765/2633 in Pushup
# Processing file 1766/2633 in Pushup
# Processing file 1767/2633 in Pushup
# Processing file 1768/2633 in Pushup
# Processing file 1769/2633 in Pushup
# Processing file 1770/2633 in Pushup
# Processing file 1771/2633 in Pushup
# Processing file 1772/2633 in Pushup
# Processing file 1773/2633 in Pushup
# Processing file 1774/2633 in Pushup
# Processing file 1775/2633 in Pushup
# Processing file 1776/2633 in Pushup
# Processing file 1777/2633 in Pushup
# Processing file 1778/2633 in Pushup
# Processing file 1779/2633 in Pushup
# Processing file 1780/2633 in Pushup
# Processing file 1781/2633 in Pushup
# Processing file 1782/2633 in Pushup
# Processing file 1783/2633 in Pushup
# Processing file 1784/2633 in Pushup
# Processing file 1785/2633 in Pushup
# Processing file 1786/2633 in Pushup
# Processing file 1787/2633 in Pushup
# Processing file 1788/2633 in Pushup
# Processing file 1789/2633 in Pushup
# Processing file 1790/2633 in Pushup
# Processing file 1791/2633 in Pushup
# Processing file 1792/2633 in Pushup
# Processing file 1793/2633 in Pushup
# Processing file 1794/2633 in Pushup
# Processing file 1795/2633 in Pushup
# Processing file 1796/2633 in Pushup
# Processing file 1797/2633 in Pushup
# Processing file 1798/2633 in Pushup
# Processing file 1799/2633 in Pushup
# Processing file 1800/2633 in Pushup
# Processing file 1801/2633 in Pushup
# Processing file 1802/2633 in Pushup
# Processing file 1803/2633 in Pushup
# Processing file 1804/2633 in Pushup
# Processing file 1805/2633 in Pushup
# Processing file 1806/2633 in Pushup
# Processing file 1807/2633 in Pushup
# Processing file 1808/2633 in Pushup
# Processing file 1809/2633 in Pushup
# Processing file 1810/2633 in Pushup
# Processing file 1811/2633 in Pushup
# Processing file 1812/2633 in Pushup
# Processing file 1813/2633 in Pushup
# Processing file 1814/2633 in Pushup
# Processing file 1815/2633 in Pushup
# Processing file 1816/2633 in Pushup
# Processing file 1817/2633 in Pushup
# Processing file 1818/2633 in Pushup
# Processing file 1819/2633 in Pushup
# Processing file 1820/2633 in Pushup
# Processing file 1821/2633 in Pushup
# Processing file 1822/2633 in Pushup
# Processing file 1823/2633 in Pushup
# Processing file 1824/2633 in Pushup
# Processing file 1825/2633 in Pushup
# Processing file 1826/2633 in Pushup
# Processing file 1827/2633 in Pushup
# Processing file 1828/2633 in Pushup
# Processing file 1829/2633 in Pushup
# Processing file 1830/2633 in Pushup
# Processing file 1831/2633 in Pushup
# Processing file 1832/2633 in Pushup
# Processing file 1833/2633 in Pushup
# Processing file 1834/2633 in Pushup
# Processing file 1835/2633 in Pushup
# Processing file 1836/2633 in Pushup
# Processing file 1837/2633 in Pushup
# Processing file 1838/2633 in Pushup
# Processing file 1839/2633 in Pushup
# Processing file 1840/2633 in Pushup
# Processing file 1841/2633 in Pushup
# Processing file 1842/2633 in Pushup
# Processing file 1843/2633 in Pushup
# Processing file 1844/2633 in Pushup
# Processing file 1845/2633 in Pushup
# Processing file 1846/2633 in Pushup
# Processing file 1847/2633 in Pushup
# Processing file 1848/2633 in Pushup
# Processing file 1849/2633 in Pushup
# Processing file 1850/2633 in Pushup
# Processing file 1851/2633 in Pushup
# Processing file 1852/2633 in Pushup
# Processing file 1853/2633 in Pushup
# Processing file 1854/2633 in Pushup
# Processing file 1855/2633 in Pushup
# Processing file 1856/2633 in Pushup
# Processing file 1857/2633 in Pushup
# Processing file 1858/2633 in Pushup
# Processing file 1859/2633 in Pushup
# Processing file 1860/2633 in Pushup
# Processing file 1861/2633 in Pushup
# Processing file 1862/2633 in Pushup
# Processing file 1863/2633 in Pushup
# Processing file 1864/2633 in Pushup
# Processing file 1865/2633 in Pushup
# Processing file 1866/2633 in Pushup
# Processing file 1867/2633 in Pushup
# Processing file 1868/2633 in Pushup
# Processing file 1869/2633 in Pushup
# Processing file 1870/2633 in Pushup
# Processing file 1871/2633 in Pushup
# Processing file 1872/2633 in Pushup
# Processing file 1873/2633 in Pushup
# Processing file 1874/2633 in Pushup
# Processing file 1875/2633 in Pushup
# Processing file 1876/2633 in Pushup
# Processing file 1877/2633 in Pushup
# Processing file 1878/2633 in Pushup
# Processing file 1879/2633 in Pushup
# Processing file 1880/2633 in Pushup
# Processing file 1881/2633 in Pushup
# Processing file 1882/2633 in Pushup
# Processing file 1883/2633 in Pushup
# Processing file 1884/2633 in Pushup
# Processing file 1885/2633 in Pushup
# Processing file 1886/2633 in Pushup
# Processing file 1887/2633 in Pushup
# Processing file 1888/2633 in Pushup
# Processing file 1889/2633 in Pushup
# Processing file 1890/2633 in Pushup
# Processing file 1891/2633 in Pushup
# Processing file 1892/2633 in Pushup
# Processing file 1893/2633 in Pushup
# Processing file 1894/2633 in Pushup
# Processing file 1895/2633 in Pushup
# Processing file 1896/2633 in Pushup
# Processing file 1897/2633 in Pushup
# Processing file 1898/2633 in Pushup
# Processing file 1899/2633 in Pushup
# Processing file 1900/2633 in Pushup
# Processing file 1901/2633 in Pushup
# Processing file 1902/2633 in Pushup
# Processing file 1903/2633 in Pushup
# Processing file 1904/2633 in Pushup
# Processing file 1905/2633 in Pushup
# Processing file 1906/2633 in Pushup
# Processing file 1907/2633 in Pushup
# Processing file 1908/2633 in Pushup
# Processing file 1909/2633 in Pushup
# Processing file 1910/2633 in Pushup
# Processing file 1911/2633 in Pushup
# Processing file 1912/2633 in Pushup
# Processing file 1913/2633 in Pushup
# Processing file 1914/2633 in Pushup
# Processing file 1915/2633 in Pushup
# Processing file 1916/2633 in Pushup
# Processing file 1917/2633 in Pushup
# Processing file 1918/2633 in Pushup
# Processing file 1919/2633 in Pushup
# Processing file 1920/2633 in Pushup
# Processing file 1921/2633 in Pushup
# Processing file 1922/2633 in Pushup
# Processing file 1923/2633 in Pushup
# Processing file 1924/2633 in Pushup
# Processing file 1925/2633 in Pushup
# Processing file 1926/2633 in Pushup
# Processing file 1927/2633 in Pushup
# Processing file 1928/2633 in Pushup
# Processing file 1929/2633 in Pushup
# Processing file 1930/2633 in Pushup
# Processing file 1931/2633 in Pushup
# Processing file 1932/2633 in Pushup
# Processing file 1933/2633 in Pushup
# Processing file 1934/2633 in Pushup
# Processing file 1935/2633 in Pushup
# Processing file 1936/2633 in Pushup
# Processing file 1937/2633 in Pushup
# Processing file 1938/2633 in Pushup
# Processing file 1939/2633 in Pushup
# Processing file 1940/2633 in Pushup
# Processing file 1941/2633 in Pushup
# Processing file 1942/2633 in Pushup
# Processing file 1943/2633 in Pushup
# Processing file 1944/2633 in Pushup
# Processing file 1945/2633 in Pushup
# Processing file 1946/2633 in Pushup
# Processing file 1947/2633 in Pushup
# Processing file 1948/2633 in Pushup
# Processing file 1949/2633 in Pushup
# Processing file 1950/2633 in Pushup
# Processing file 1951/2633 in Pushup
# Processing file 1952/2633 in Pushup
# Processing file 1953/2633 in Pushup
# Processing file 1954/2633 in Pushup
# Processing file 1955/2633 in Pushup
# Processing file 1956/2633 in Pushup
# Processing file 1957/2633 in Pushup
# Processing file 1958/2633 in Pushup
# Processing file 1959/2633 in Pushup
# Processing file 1960/2633 in Pushup
# Processing file 1961/2633 in Pushup
# Processing file 1962/2633 in Pushup
# Processing file 1963/2633 in Pushup
# Processing file 1964/2633 in Pushup
# Processing file 1965/2633 in Pushup
# Processing file 1966/2633 in Pushup
# Processing file 1967/2633 in Pushup
# Processing file 1968/2633 in Pushup
# Processing file 1969/2633 in Pushup
# Processing file 1970/2633 in Pushup
# Processing file 1971/2633 in Pushup
# Processing file 1972/2633 in Pushup
# Processing file 1973/2633 in Pushup
# Processing file 1974/2633 in Pushup
# Processing file 1975/2633 in Pushup
# Processing file 1976/2633 in Pushup
# Processing file 1977/2633 in Pushup
# Processing file 1978/2633 in Pushup
# Processing file 1979/2633 in Pushup
# Processing file 1980/2633 in Pushup
# Processing file 1981/2633 in Pushup
# Processing file 1982/2633 in Pushup
# Processing file 1983/2633 in Pushup
# Processing file 1984/2633 in Pushup
# Processing file 1985/2633 in Pushup
# Processing file 1986/2633 in Pushup
# Processing file 1987/2633 in Pushup
# Processing file 1988/2633 in Pushup
# Processing file 1989/2633 in Pushup
# Processing file 1990/2633 in Pushup
# Processing file 1991/2633 in Pushup
# Processing file 1992/2633 in Pushup
# Processing file 1993/2633 in Pushup
# Processing file 1994/2633 in Pushup
# Processing file 1995/2633 in Pushup
# Processing file 1996/2633 in Pushup
# Processing file 1997/2633 in Pushup
# Processing file 1998/2633 in Pushup
# Processing file 1999/2633 in Pushup
# Processing file 2000/2633 in Pushup
# Processing file 2001/2633 in Pushup
# Processing file 2002/2633 in Pushup
# Processing file 2003/2633 in Pushup
# Processing file 2004/2633 in Pushup
# Processing file 2005/2633 in Pushup
# Processing file 2006/2633 in Pushup
# Processing file 2007/2633 in Pushup
# Processing file 2008/2633 in Pushup
# Processing file 2009/2633 in Pushup
# Processing file 2010/2633 in Pushup
# Processing file 2011/2633 in Pushup
# Processing file 2012/2633 in Pushup
# Processing file 2013/2633 in Pushup
# Processing file 2014/2633 in Pushup
# Processing file 2015/2633 in Pushup
# Processing file 2016/2633 in Pushup
# Processing file 2017/2633 in Pushup
# Processing file 2018/2633 in Pushup
# Processing file 2019/2633 in Pushup
# Processing file 2020/2633 in Pushup
# Processing file 2021/2633 in Pushup
# Processing file 2022/2633 in Pushup
# Processing file 2023/2633 in Pushup
# Processing file 2024/2633 in Pushup
# Processing file 2025/2633 in Pushup
# Processing file 2026/2633 in Pushup
# Processing file 2027/2633 in Pushup
# Processing file 2028/2633 in Pushup
# Processing file 2029/2633 in Pushup
# Processing file 2030/2633 in Pushup
# Processing file 2031/2633 in Pushup
# Processing file 2032/2633 in Pushup
# Processing file 2033/2633 in Pushup
# Processing file 2034/2633 in Pushup
# Processing file 2035/2633 in Pushup
# Processing file 2036/2633 in Pushup
# Processing file 2037/2633 in Pushup
# Processing file 2038/2633 in Pushup
# Processing file 2039/2633 in Pushup
# Processing file 2040/2633 in Pushup
# Processing file 2041/2633 in Pushup
# Processing file 2042/2633 in Pushup
# Processing file 2043/2633 in Pushup
# Processing file 2044/2633 in Pushup
# Processing file 2045/2633 in Pushup
# Processing file 2046/2633 in Pushup
# Processing file 2047/2633 in Pushup
# Processing file 2048/2633 in Pushup
# Processing file 2049/2633 in Pushup
# Processing file 2050/2633 in Pushup
# Processing file 2051/2633 in Pushup
# Processing file 2052/2633 in Pushup
# Processing file 2053/2633 in Pushup
# Processing file 2054/2633 in Pushup
# Processing file 2055/2633 in Pushup
# Processing file 2056/2633 in Pushup
# Processing file 2057/2633 in Pushup
# Processing file 2058/2633 in Pushup
# Processing file 2059/2633 in Pushup
# Processing file 2060/2633 in Pushup
# Processing file 2061/2633 in Pushup
# Processing file 2062/2633 in Pushup
# Processing file 2063/2633 in Pushup
# Processing file 2064/2633 in Pushup
# Processing file 2065/2633 in Pushup
# Processing file 2066/2633 in Pushup
# Processing file 2067/2633 in Pushup
# Processing file 2068/2633 in Pushup
# Processing file 2069/2633 in Pushup
# Processing file 2070/2633 in Pushup
# Processing file 2071/2633 in Pushup
# Processing file 2072/2633 in Pushup
# Processing file 2073/2633 in Pushup
# Processing file 2074/2633 in Pushup
# Processing file 2075/2633 in Pushup
# Processing file 2076/2633 in Pushup
# Processing file 2077/2633 in Pushup
# Processing file 2078/2633 in Pushup
# Processing file 2079/2633 in Pushup
# Processing file 2080/2633 in Pushup
# Processing file 2081/2633 in Pushup
# Processing file 2082/2633 in Pushup
# Processing file 2083/2633 in Pushup
# Processing file 2084/2633 in Pushup
# Processing file 2085/2633 in Pushup
# Processing file 2086/2633 in Pushup
# Processing file 2087/2633 in Pushup
# Processing file 2088/2633 in Pushup
# Processing file 2089/2633 in Pushup
# Processing file 2090/2633 in Pushup
# Processing file 2091/2633 in Pushup
# Processing file 2092/2633 in Pushup
# Processing file 2093/2633 in Pushup
# Processing file 2094/2633 in Pushup
# Processing file 2095/2633 in Pushup
# Processing file 2096/2633 in Pushup
# Processing file 2097/2633 in Pushup
# Processing file 2098/2633 in Pushup
# Processing file 2099/2633 in Pushup
# Processing file 2100/2633 in Pushup
# Processing file 2101/2633 in Pushup
# Processing file 2102/2633 in Pushup
# Processing file 2103/2633 in Pushup
# Processing file 2104/2633 in Pushup
# Processing file 2105/2633 in Pushup
# Processing file 2106/2633 in Pushup
# Processing file 2107/2633 in Pushup
# Processing file 2108/2633 in Pushup
# Processing file 2109/2633 in Pushup
# Processing file 2110/2633 in Pushup
# Processing file 2111/2633 in Pushup
# Processing file 2112/2633 in Pushup
# Processing file 2113/2633 in Pushup
# Processing file 2114/2633 in Pushup
# Processing file 2115/2633 in Pushup
# Processing file 2116/2633 in Pushup
# Processing file 2117/2633 in Pushup
# Processing file 2118/2633 in Pushup
# Processing file 2119/2633 in Pushup
# Processing file 2120/2633 in Pushup
# Processing file 2121/2633 in Pushup
# Processing file 2122/2633 in Pushup
# Processing file 2123/2633 in Pushup
# Processing file 2124/2633 in Pushup
# Processing file 2125/2633 in Pushup
# Processing file 2126/2633 in Pushup
# Processing file 2127/2633 in Pushup
# Processing file 2128/2633 in Pushup
# Processing file 2129/2633 in Pushup
# Processing file 2130/2633 in Pushup
# Processing file 2131/2633 in Pushup
# Processing file 2132/2633 in Pushup
# Processing file 2133/2633 in Pushup
# Processing file 2134/2633 in Pushup
# Processing file 2135/2633 in Pushup
# Processing file 2136/2633 in Pushup
# Processing file 2137/2633 in Pushup
# Processing file 2138/2633 in Pushup
# Processing file 2139/2633 in Pushup
# Processing file 2140/2633 in Pushup
# Processing file 2141/2633 in Pushup
# Processing file 2142/2633 in Pushup
# Processing file 2143/2633 in Pushup
# Processing file 2144/2633 in Pushup
# Processing file 2145/2633 in Pushup
# Processing file 2146/2633 in Pushup
# Processing file 2147/2633 in Pushup
# Processing file 2148/2633 in Pushup
# Processing file 2149/2633 in Pushup
# Processing file 2150/2633 in Pushup
# Processing file 2151/2633 in Pushup
# Processing file 2152/2633 in Pushup
# Processing file 2153/2633 in Pushup
# Processing file 2154/2633 in Pushup
# Processing file 2155/2633 in Pushup
# Processing file 2156/2633 in Pushup
# Processing file 2157/2633 in Pushup
# Processing file 2158/2633 in Pushup
# Processing file 2159/2633 in Pushup
# Processing file 2160/2633 in Pushup
# Processing file 2161/2633 in Pushup
# Processing file 2162/2633 in Pushup
# Processing file 2163/2633 in Pushup
# Processing file 2164/2633 in Pushup
# Processing file 2165/2633 in Pushup
# Processing file 2166/2633 in Pushup
# Processing file 2167/2633 in Pushup
# Processing file 2168/2633 in Pushup
# Processing file 2169/2633 in Pushup
# Processing file 2170/2633 in Pushup
# Processing file 2171/2633 in Pushup
# Processing file 2172/2633 in Pushup
# Processing file 2173/2633 in Pushup
# Processing file 2174/2633 in Pushup
# Processing file 2175/2633 in Pushup
# Processing file 2176/2633 in Pushup
# Processing file 2177/2633 in Pushup
# Processing file 2178/2633 in Pushup
# Processing file 2179/2633 in Pushup
# Processing file 2180/2633 in Pushup
# Processing file 2181/2633 in Pushup
# Processing file 2182/2633 in Pushup
# Processing file 2183/2633 in Pushup
# Processing file 2184/2633 in Pushup
# Processing file 2185/2633 in Pushup
# Processing file 2186/2633 in Pushup
# Processing file 2187/2633 in Pushup
# Processing file 2188/2633 in Pushup
# Processing file 2189/2633 in Pushup
# Processing file 2190/2633 in Pushup
# Processing file 2191/2633 in Pushup
# Processing file 2192/2633 in Pushup
# Processing file 2193/2633 in Pushup
# Processing file 2194/2633 in Pushup
# Processing file 2195/2633 in Pushup
# Processing file 2196/2633 in Pushup
# Processing file 2197/2633 in Pushup
# Processing file 2198/2633 in Pushup
# Processing file 2199/2633 in Pushup
# Processing file 2200/2633 in Pushup
# Processing file 2201/2633 in Pushup
# Processing file 2202/2633 in Pushup
# Processing file 2203/2633 in Pushup
# Processing file 2204/2633 in Pushup
# Processing file 2205/2633 in Pushup
# Processing file 2206/2633 in Pushup
# Processing file 2207/2633 in Pushup
# Processing file 2208/2633 in Pushup
# Processing file 2209/2633 in Pushup
# Processing file 2210/2633 in Pushup
# Processing file 2211/2633 in Pushup
# Processing file 2212/2633 in Pushup
# Processing file 2213/2633 in Pushup
# Processing file 2214/2633 in Pushup
# Processing file 2215/2633 in Pushup
# Processing file 2216/2633 in Pushup
# Processing file 2217/2633 in Pushup
# Processing file 2218/2633 in Pushup
# Processing file 2219/2633 in Pushup
# Processing file 2220/2633 in Pushup
# Processing file 2221/2633 in Pushup
# Processing file 2222/2633 in Pushup
# Processing file 2223/2633 in Pushup
# Processing file 2224/2633 in Pushup
# Processing file 2225/2633 in Pushup
# Processing file 2226/2633 in Pushup
# Processing file 2227/2633 in Pushup
# Processing file 2228/2633 in Pushup
# Processing file 2229/2633 in Pushup
# Processing file 2230/2633 in Pushup
# Processing file 2231/2633 in Pushup
# Processing file 2232/2633 in Pushup
# Processing file 2233/2633 in Pushup
# Processing file 2234/2633 in Pushup
# Processing file 2235/2633 in Pushup
# Processing file 2236/2633 in Pushup
# Processing file 2237/2633 in Pushup
# Processing file 2238/2633 in Pushup
# Processing file 2239/2633 in Pushup
# Processing file 2240/2633 in Pushup
# Processing file 2241/2633 in Pushup
# Processing file 2242/2633 in Pushup
# Processing file 2243/2633 in Pushup
# Processing file 2244/2633 in Pushup
# Processing file 2245/2633 in Pushup
# Processing file 2246/2633 in Pushup
# Processing file 2247/2633 in Pushup
# Processing file 2248/2633 in Pushup
# Processing file 2249/2633 in Pushup
# Processing file 2250/2633 in Pushup
# Processing file 2251/2633 in Pushup
# Processing file 2252/2633 in Pushup
# Processing file 2253/2633 in Pushup
# Processing file 2254/2633 in Pushup
# Processing file 2255/2633 in Pushup
# Processing file 2256/2633 in Pushup
# Processing file 2257/2633 in Pushup
# Processing file 2258/2633 in Pushup
# Processing file 2259/2633 in Pushup
# Processing file 2260/2633 in Pushup
# Processing file 2261/2633 in Pushup
# Processing file 2262/2633 in Pushup
# Processing file 2263/2633 in Pushup
# Processing file 2264/2633 in Pushup
# Processing file 2265/2633 in Pushup
# Processing file 2266/2633 in Pushup
# Processing file 2267/2633 in Pushup
# Processing file 2268/2633 in Pushup
# Processing file 2269/2633 in Pushup
# Processing file 2270/2633 in Pushup
# Processing file 2271/2633 in Pushup
# Processing file 2272/2633 in Pushup
# Processing file 2273/2633 in Pushup
# Processing file 2274/2633 in Pushup
# Processing file 2275/2633 in Pushup
# Processing file 2276/2633 in Pushup
# Processing file 2277/2633 in Pushup
# Processing file 2278/2633 in Pushup
# Processing file 2279/2633 in Pushup
# Processing file 2280/2633 in Pushup
# Processing file 2281/2633 in Pushup
# Processing file 2282/2633 in Pushup
# Processing file 2283/2633 in Pushup
# Processing file 2284/2633 in Pushup
# Processing file 2285/2633 in Pushup
# Processing file 2286/2633 in Pushup
# Processing file 2287/2633 in Pushup
# Processing file 2288/2633 in Pushup
# Processing file 2289/2633 in Pushup
# Processing file 2290/2633 in Pushup
# Processing file 2291/2633 in Pushup
# Processing file 2292/2633 in Pushup
# Processing file 2293/2633 in Pushup
# Processing file 2294/2633 in Pushup
# Processing file 2295/2633 in Pushup
# Processing file 2296/2633 in Pushup
# Processing file 2297/2633 in Pushup
# Processing file 2298/2633 in Pushup
# Processing file 2299/2633 in Pushup
# Processing file 2300/2633 in Pushup
# Processing file 2301/2633 in Pushup
# Processing file 2302/2633 in Pushup
# Processing file 2303/2633 in Pushup
# Processing file 2304/2633 in Pushup
# Processing file 2305/2633 in Pushup
# Processing file 2306/2633 in Pushup
# Processing file 2307/2633 in Pushup
# Processing file 2308/2633 in Pushup
# Processing file 2309/2633 in Pushup
# Processing file 2310/2633 in Pushup
# Processing file 2311/2633 in Pushup
# Processing file 2312/2633 in Pushup
# Processing file 2313/2633 in Pushup
# Processing file 2314/2633 in Pushup
# Processing file 2315/2633 in Pushup
# Processing file 2316/2633 in Pushup
# Processing file 2317/2633 in Pushup
# Processing file 2318/2633 in Pushup
# Processing file 2319/2633 in Pushup
# Processing file 2320/2633 in Pushup
# Processing file 2321/2633 in Pushup
# Processing file 2322/2633 in Pushup
# ...
# Processing file 771/1197 in Other
# Processing file 772/1197 in Other
# Processing file 773/1197 in Other
# Processing file 774/1197 in Other
# Processing file 775/1197 in Other
# Processing file 776/1197 in Other
# Processing file 777/1197 in Other
# Processing file 778/1197 in Other
# Processing file 779/1197 in Other
# Processing file 780/1197 in Other
# Processing file 781/1197 in Other
# Processing file 782/1197 in Other
# Processing file 783/1197 in Other
# Processing file 784/1197 in Other
# Processing file 785/1197 in Other
# Processing file 786/1197 in Other
# Processing file 787/1197 in Other
# Processing file 788/1197 in Other
# Processing file 789/1197 in Other
# Processing file 790/1197 in Other
# Processing file 791/1197 in Other
# Processing file 792/1197 in Other
# Processing file 793/1197 in Other
# Processing file 794/1197 in Other
# Processing file 795/1197 in Other
# Processing file 796/1197 in Other
# Processing file 797/1197 in Other
# Processing file 798/1197 in Other
# Processing file 799/1197 in Other
# Processing file 800/1197 in Other
# Processing file 801/1197 in Other
# Processing file 802/1197 in Other
# Processing file 803/1197 in Other
# Processing file 804/1197 in Other
# Processing file 805/1197 in Other
# Processing file 806/1197 in Other
# Processing file 807/1197 in Other
# Processing file 808/1197 in Other
# Processing file 809/1197 in Other
# Processing file 810/1197 in Other
# Processing file 811/1197 in Other
# Processing file 812/1197 in Other
# Processing file 813/1197 in Other
# Processing file 814/1197 in Other
# Processing file 815/1197 in Other
# Processing file 816/1197 in Other
# Processing file 817/1197 in Other
# Processing file 818/1197 in Other
# Processing file 819/1197 in Other
# Processing file 820/1197 in Other
# Processing file 821/1197 in Other
# Processing file 822/1197 in Other
# Processing file 823/1197 in Other
# Processing file 824/1197 in Other
# Processing file 825/1197 in Other
# Processing file 826/1197 in Other
# Processing file 827/1197 in Other
# Processing file 828/1197 in Other
# Processing file 829/1197 in Other
# Processing file 830/1197 in Other
# Processing file 831/1197 in Other
# Processing file 832/1197 in Other
# Processing file 833/1197 in Other
# An error occurred when processing file: IMG_3945_mov-0655_jpg.rf.1853b48a69b6b78327d2b95d67cadf51.jpg
# Processing file 834/1197 in Other
# Processing file 835/1197 in Other
# Processing file 836/1197 in Other
# Processing file 837/1197 in Other
# Processing file 838/1197 in Other
# Processing file 839/1197 in Other
# Processing file 840/1197 in Other
# Processing file 841/1197 in Other
# Processing file 842/1197 in Other
# Processing file 843/1197 in Other
# Processing file 844/1197 in Other
# Processing file 845/1197 in Other
# Processing file 846/1197 in Other
# Processing file 847/1197 in Other
# Processing file 848/1197 in Other
# Processing file 849/1197 in Other
# Processing file 850/1197 in Other
# Processing file 851/1197 in Other
# Processing file 852/1197 in Other
# Processing file 853/1197 in Other
# Processing file 854/1197 in Other
# Processing file 855/1197 in Other
# Processing file 856/1197 in Other
# Processing file 857/1197 in Other
# Processing file 858/1197 in Other
# Processing file 859/1197 in Other
# Processing file 860/1197 in Other
# Processing file 861/1197 in Other
# Processing file 862/1197 in Other
# Processing file 863/1197 in Other
# Processing file 864/1197 in Other
# Processing file 865/1197 in Other
# Processing file 866/1197 in Other
# Processing file 867/1197 in Other
# Processing file 868/1197 in Other
# Processing file 869/1197 in Other
# Processing file 870/1197 in Other
# Processing file 871/1197 in Other
# Processing file 872/1197 in Other
# Processing file 873/1197 in Other
# Processing file 874/1197 in Other
# Processing file 875/1197 in Other
# Processing file 876/1197 in Other
# Processing file 877/1197 in Other
# Processing file 878/1197 in Other
# Processing file 879/1197 in Other
# Processing file 880/1197 in Other
# Processing file 881/1197 in Other
# Processing file 882/1197 in Other
# Processing file 883/1197 in Other
# Processing file 884/1197 in Other
# Processing file 885/1197 in Other
# Processing file 886/1197 in Other
# Processing file 887/1197 in Other
# Processing file 888/1197 in Other
# Processing file 889/1197 in Other
# Processing file 890/1197 in Other
# Processing file 891/1197 in Other
# Processing file 892/1197 in Other
# Processing file 893/1197 in Other
# Processing file 894/1197 in Other
# Processing file 895/1197 in Other
# Processing file 896/1197 in Other
# An error occurred when processing file: IMG_3947_mov-0879_jpg.rf.a15c527c1019964c8927f5740fe53208.jpg
# Processing file 897/1197 in Other
# Processing file 898/1197 in Other
# Processing file 899/1197 in Other
# Processing file 900/1197 in Other
# An error occurred when processing file: IMG_3945_mov-0653_jpg.rf.5b736728531f3d9dc9436563f018ae21.jpg
# Processing file 901/1197 in Other
# An error occurred when processing file: IMG_3947_mov-0875_jpg.rf.7e4f9d67b0afa6c55eb93ed3ee51c135.jpg
# Processing file 902/1197 in Other
# Processing file 903/1197 in Other
# Processing file 904/1197 in Other
# Processing file 905/1197 in Other
# Processing file 906/1197 in Other
# Processing file 907/1197 in Other
# Processing file 908/1197 in Other
# Processing file 909/1197 in Other
# Processing file 910/1197 in Other
# Processing file 911/1197 in Other
# Processing file 912/1197 in Other
# Processing file 913/1197 in Other
# Processing file 914/1197 in Other
# Processing file 915/1197 in Other
# Processing file 916/1197 in Other
# Processing file 917/1197 in Other
# Processing file 918/1197 in Other
# Processing file 919/1197 in Other
# Processing file 920/1197 in Other
# Processing file 921/1197 in Other
# Processing file 922/1197 in Other
# Processing file 923/1197 in Other
# Processing file 924/1197 in Other
# Processing file 925/1197 in Other
# Processing file 926/1197 in Other
# Processing file 927/1197 in Other
# Processing file 928/1197 in Other
# Processing file 929/1197 in Other
# Processing file 930/1197 in Other
# Processing file 931/1197 in Other
# Processing file 932/1197 in Other
# Processing file 933/1197 in Other
# Processing file 934/1197 in Other
# Processing file 935/1197 in Other
# Processing file 936/1197 in Other
# Processing file 937/1197 in Other
# An error occurred when processing file: IMG_3945_mov-0653_jpg.rf.e1e56538f6dac403d7cc273a3847ddfe.jpg
# Processing file 938/1197 in Other
# Processing file 939/1197 in Other
# Processing file 940/1197 in Other
# Processing file 941/1197 in Other
# Processing file 942/1197 in Other
# Processing file 943/1197 in Other
# Processing file 944/1197 in Other
# Processing file 945/1197 in Other
# Processing file 946/1197 in Other
# Processing file 947/1197 in Other
# Processing file 948/1197 in Other
# Processing file 949/1197 in Other
# Processing file 950/1197 in Other
# Processing file 951/1197 in Other
# Processing file 952/1197 in Other
# Processing file 953/1197 in Other
# Processing file 954/1197 in Other
# Processing file 955/1197 in Other
# Processing file 956/1197 in Other
# Processing file 957/1197 in Other
# Processing file 958/1197 in Other
# Processing file 959/1197 in Other
# Processing file 960/1197 in Other
# Processing file 961/1197 in Other
# Processing file 962/1197 in Other
# Processing file 963/1197 in Other
# Processing file 964/1197 in Other
# Processing file 965/1197 in Other
# Processing file 966/1197 in Other
# Processing file 967/1197 in Other
# Processing file 968/1197 in Other
# Processing file 969/1197 in Other
# Processing file 970/1197 in Other
# Processing file 971/1197 in Other
# Processing file 972/1197 in Other
# Processing file 973/1197 in Other
# Processing file 974/1197 in Other
# Processing file 975/1197 in Other
# Processing file 976/1197 in Other
# Processing file 977/1197 in Other
# Processing file 978/1197 in Other
# Processing file 979/1197 in Other
# Processing file 980/1197 in Other
# Processing file 981/1197 in Other
# Processing file 982/1197 in Other
# Processing file 983/1197 in Other
# Processing file 984/1197 in Other
# Processing file 985/1197 in Other
# Processing file 986/1197 in Other
# Processing file 987/1197 in Other
# Processing file 988/1197 in Other
# Processing file 989/1197 in Other
# Processing file 990/1197 in Other
# Processing file 991/1197 in Other
# Processing file 992/1197 in Other
# Processing file 993/1197 in Other
# Processing file 994/1197 in Other
# Processing file 995/1197 in Other
# Processing file 996/1197 in Other
# Processing file 997/1197 in Other
# Processing file 998/1197 in Other
# Processing file 999/1197 in Other
# Processing file 1000/1197 in Other
# Processing file 1001/1197 in Other
# Processing file 1002/1197 in Other
# Processing file 1003/1197 in Other
# Processing file 1004/1197 in Other
# Processing file 1005/1197 in Other
# Processing file 1006/1197 in Other
# Processing file 1007/1197 in Other
# Processing file 1008/1197 in Other
# Processing file 1009/1197 in Other
# Processing file 1010/1197 in Other
# Processing file 1011/1197 in Other
# Processing file 1012/1197 in Other
# Processing file 1013/1197 in Other
# Processing file 1014/1197 in Other
# Processing file 1015/1197 in Other
# Processing file 1016/1197 in Other
# Processing file 1017/1197 in Other
# Processing file 1018/1197 in Other
# Processing file 1019/1197 in Other
# Processing file 1020/1197 in Other
# An error occurred when processing file: IMG_3947_mov-0871_jpg.rf.3e94845727eb489c06ce96bfd9d9f2f2.jpg
# Processing file 1021/1197 in Other
# Processing file 1022/1197 in Other
# Processing file 1023/1197 in Other
# Processing file 1024/1197 in Other
# Processing file 1025/1197 in Other
# Processing file 1026/1197 in Other
# Processing file 1027/1197 in Other
# Processing file 1028/1197 in Other
# Processing file 1029/1197 in Other
# Processing file 1030/1197 in Other
# Processing file 1031/1197 in Other
# Processing file 1032/1197 in Other
# Processing file 1033/1197 in Other
# Processing file 1034/1197 in Other
# Processing file 1035/1197 in Other
# Processing file 1036/1197 in Other
# Processing file 1037/1197 in Other
# Processing file 1038/1197 in Other
# Processing file 1039/1197 in Other
# Processing file 1040/1197 in Other
# Processing file 1041/1197 in Other
# Processing file 1042/1197 in Other
# Processing file 1043/1197 in Other
# Processing file 1044/1197 in Other
# Processing file 1045/1197 in Other
# Processing file 1046/1197 in Other
# Processing file 1047/1197 in Other
# Processing file 1048/1197 in Other
# Processing file 1049/1197 in Other
# Processing file 1050/1197 in Other
# Processing file 1051/1197 in Other
# Processing file 1052/1197 in Other
# Processing file 1053/1197 in Other
# Processing file 1054/1197 in Other
# Processing file 1055/1197 in Other
# Processing file 1056/1197 in Other
# Processing file 1057/1197 in Other
# Processing file 1058/1197 in Other
# Processing file 1059/1197 in Other
# Processing file 1060/1197 in Other
# Processing file 1061/1197 in Other
# Processing file 1062/1197 in Other
# Processing file 1063/1197 in Other
# Processing file 1064/1197 in Other
# Processing file 1065/1197 in Other
# Processing file 1066/1197 in Other
# Processing file 1067/1197 in Other
# Processing file 1068/1197 in Other
# Processing file 1069/1197 in Other
# Processing file 1070/1197 in Other
# Processing file 1071/1197 in Other
# Processing file 1072/1197 in Other
# Processing file 1073/1197 in Other
# Processing file 1074/1197 in Other
# An error occurred when processing file: IMG_3945_mov-0639_jpg.rf.e3bf253b09f249b2eaaee706508850ed.jpg
# Processing file 1075/1197 in Other
# Processing file 1076/1197 in Other
# Processing file 1077/1197 in Other
# Processing file 1078/1197 in Other
# Processing file 1079/1197 in Other
# Processing file 1080/1197 in Other
# Processing file 1081/1197 in Other
# Processing file 1082/1197 in Other
# Processing file 1083/1197 in Other
# Processing file 1084/1197 in Other
# Processing file 1085/1197 in Other
# Processing file 1086/1197 in Other
# Processing file 1087/1197 in Other
# Processing file 1088/1197 in Other
# Processing file 1089/1197 in Other
# Processing file 1090/1197 in Other
# Processing file 1091/1197 in Other
# Processing file 1092/1197 in Other
# Processing file 1093/1197 in Other
# Processing file 1094/1197 in Other
# Processing file 1095/1197 in Other
# Processing file 1096/1197 in Other
# Processing file 1097/1197 in Other
# An error occurred when processing file: IMG_3945_mov-0658_jpg.rf.21ea4d88dbe51da4af2de5188ba7055b.jpg
# Processing file 1098/1197 in Other
# Processing file 1099/1197 in Other
# Processing file 1100/1197 in Other
# Processing file 1101/1197 in Other
# Processing file 1102/1197 in Other
# Processing file 1103/1197 in Other
# Processing file 1104/1197 in Other
# Processing file 1105/1197 in Other
# Processing file 1106/1197 in Other
# Processing file 1107/1197 in Other
# Processing file 1108/1197 in Other
# Processing file 1109/1197 in Other
# An error occurred when processing file: IMG_3945_mov-0642_jpg.rf.e439bf5e11a2db20a9e5b27f356b484c.jpg
# Processing file 1110/1197 in Other
# Processing file 1111/1197 in Other
# Processing file 1112/1197 in Other
# Processing file 1113/1197 in Other
# Processing file 1114/1197 in Other
# An error occurred when processing file: IMG_3947_mov-0873_jpg.rf.a3aa09190535471c610a80fa28c9b95b.jpg
# Processing file 1115/1197 in Other
# Processing file 1116/1197 in Other
# Processing file 1117/1197 in Other
# Processing file 1118/1197 in Other
# Processing file 1119/1197 in Other
# Processing file 1120/1197 in Other
# Processing file 1121/1197 in Other
# Processing file 1122/1197 in Other
# Processing file 1123/1197 in Other
# Processing file 1124/1197 in Other
# Processing file 1125/1197 in Other
# An error occurred when processing file: IMG_3947_mov-0872_jpg.rf.a3de5a043b41b2e7a68e3dfaaefc0de6.jpg
# Processing file 1126/1197 in Other
# Processing file 1127/1197 in Other
# Processing file 1128/1197 in Other
# Processing file 1129/1197 in Other
# Processing file 1130/1197 in Other
# Processing file 1131/1197 in Other
# Processing file 1132/1197 in Other
# Processing file 1133/1197 in Other
# Processing file 1134/1197 in Other
# Processing file 1135/1197 in Other
# Processing file 1136/1197 in Other
# Processing file 1137/1197 in Other
# Processing file 1138/1197 in Other
# Processing file 1139/1197 in Other
# Processing file 1140/1197 in Other
# Processing file 1141/1197 in Other
# Processing file 1142/1197 in Other
# Processing file 1143/1197 in Other
# Processing file 1144/1197 in Other
# Processing file 1145/1197 in Other
# Processing file 1146/1197 in Other
# Processing file 1147/1197 in Other
# Processing file 1148/1197 in Other
# Processing file 1149/1197 in Other
# Processing file 1150/1197 in Other
# Processing file 1151/1197 in Other
# Processing file 1152/1197 in Other
# Processing file 1153/1197 in Other
# Processing file 1154/1197 in Other
# Processing file 1155/1197 in Other
# Processing file 1156/1197 in Other
# Processing file 1157/1197 in Other
# Processing file 1158/1197 in Other
# Processing file 1159/1197 in Other
# Processing file 1160/1197 in Other
# Processing file 1161/1197 in Other
# Processing file 1162/1197 in Other
# Processing file 1163/1197 in Other
# Processing file 1164/1197 in Other
# Processing file 1165/1197 in Other
# Processing file 1166/1197 in Other
# Processing file 1167/1197 in Other
# Processing file 1168/1197 in Other
# Processing file 1169/1197 in Other
# An error occurred when processing file: IMG_3945_mov-0643_jpg.rf.ca27d6ba1fe82be0f5f633cef5161b14.jpg
# Processing file 1170/1197 in Other
# Processing file 1171/1197 in Other
# Processing file 1172/1197 in Other
# Processing file 1173/1197 in Other
# Processing file 1174/1197 in Other
# Processing file 1175/1197 in Other
# Processing file 1176/1197 in Other
# Processing file 1177/1197 in Other
# Processing file 1178/1197 in Other
# Processing file 1179/1197 in Other
# Processing file 1180/1197 in Other
# Processing file 1181/1197 in Other
# Processing file 1182/1197 in Other
# Processing file 1183/1197 in Other
# Processing file 1184/1197 in Other
# Processing file 1185/1197 in Other
# Processing file 1186/1197 in Other
# Processing file 1187/1197 in Other
# Processing file 1188/1197 in Other
# Processing file 1189/1197 in Other
# Processing file 1190/1197 in Other
# Processing file 1191/1197 in Other
# Processing file 1192/1197 in Other
# Processing file 1193/1197 in Other
# Processing file 1194/1197 in Other
# Processing file 1195/1197 in Other
# Processing file 1196/1197 in Other
# Processing file 1197/1197 in Other

# %%
len(output[1])
# Out:
# 8

# %%
# prompt: Turn a 2d array into a dataframe with 8 columns
def generate_metadata_csv(dataset_path, filename, metadata_path)
import pandas as pd

# Convert the 2D array to a DataFrame
df = pd.DataFrame(output)

# Rename the columns
df.columns = [
    "Left Elbow Angle",
    "Right Elbow Angle",
    "Left Shoulder Angle",
    "Right Shoulder Angle",
    "Left Hip Angle",
    "Right Hip Angle",
    "Left Knee Angle",
    "Right Knee Angle",
]

# Print the DataFrame
print(df)
# Out:
#     Left Elbow Angle  Right Elbow Angle  Left Shoulder Angle  \
# 0          25.159548          37.457580            47.862926
# 1          34.484286          46.667032            36.296629
# 2          23.974305          27.536796            37.906252
# 3          32.470883          47.118521            32.634815
# 4          35.216080          45.670292            35.366043
# 5          28.485283          38.405471            29.834635
# 6          34.616669          39.716225            35.868383
# 7          28.877500          40.373316            32.419793
# 8          12.195883          37.181969            47.304394
# 9          34.023187          43.809113            34.336932
# 10         36.268434          35.646768            50.093284
# 11         20.280450          45.051962            32.761173
# 12         35.961697          61.490663           124.631599
# 13         32.248151          41.063360            32.435059
# 14         19.457802          33.163762            43.146346
# 15         27.563228          45.865728            32.642628
# 16         31.281358          33.607369            52.143440
# 17         64.918598          50.469702            70.795198
# 18         24.598018          41.479428            31.110473
# 19         20.598116          26.922318            44.027454
# 20         25.797508          42.755352            32.413045
# 21         23.705736          38.749565            38.218795
# 22         32.546200          39.150846            51.060438
# 23         39.080963          42.137851            36.045907
# 24         38.980969          22.007928            50.448460
# 25         30.855427          46.680928            32.050342
# 26         33.652766          46.496516            35.964204
# 27         33.837993          46.129192            33.771023
# 28         27.797818          40.467665            29.546551
# 29         37.749697          40.512099            47.766259
#
#     Right Shoulder Angle  Left Hip Angle  Right Hip Angle  Left Knee Angle  \
# 0              45.366834      109.350564       176.738890       113.582949
# 1              44.321098      152.072714       174.809693       156.129426
# 2              47.235532       86.980956       143.058616        80.737471
# 3              43.760940      163.984714       170.487946       172.224111
# 4              39.660484      163.679118       170.037823       171.811377
# 5              44.795871      167.488109       173.013326       169.194322
# 6              46.926876      161.527171       168.077148       172.691570
# 7              42.748549      165.581599       168.636049       173.604438
# 8              47.484588      107.627245       177.026632       115.233641
# 9              42.973146      164.565813       169.557005       171.941915
# 10             45.929580      114.035035       179.479422       123.930631
# 11             45.080574      162.260583       173.744279       167.631328
# 12             12.079408      176.767171       175.913479        53.343573
# 13             43.476845      164.391807       169.955532       172.859702
# 14             50.059488       84.454347       160.073615        77.594135
# 15             43.408304      165.582965       167.216449       172.910846
# 16             44.398449      107.145560       169.608214       116.535667
# 17             64.110785      155.272494       179.786152       158.715582
# 18             42.987824      168.346664       169.680262       171.423449
# 19             50.179870       86.014048       159.471001        80.057593
# 20             42.232706      165.802391       168.706018       174.820335
# 21             44.227927      128.461515       179.412667       130.174571
# 22             42.693245       96.819257       165.810833        96.546845
# 23             49.536288      165.667563       168.090959       170.780100
# 24             48.481625       83.325528       172.105280        83.219151
# 25             44.534514      163.526490       170.909232       173.925648
# 26             43.022078      165.070864       169.555871       175.443535
# 27             45.629816      163.272571       170.694846       172.161219
# 28             42.485231      164.372491       169.488675       172.811398
# 29             40.784111      161.467680       179.994049       168.404902
#
#     Right Knee Angle
# 0         165.880437
# 1         172.452076
# 2         162.557177
# 3         178.676956
# 4         175.149601
# 5         178.592016
# 6         172.150656
# 7         176.262676
# 8         172.164662
# 9         176.870672
# 10        173.048789
# 11        178.507845
# 12         50.437354
# 13        177.487984
# 14        178.075244
# 15        174.820959
# 16        162.823640
# 17        173.727514
# 18        174.611682
# 19        176.288712
# 20        173.829189
# 21        168.307941
# 22        151.610819
# 23        175.637167
# 24        176.896890
# 25        178.360965
# 26        176.628801
# 27        176.878349
# 28        177.621638
# 29        170.245744

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f0d7fbd40980> in <cell line: 2>()
#       1 # Compute correlation matrix for your features
# ----> 2 correlation_matrix = X_train.corr()
#       3
#       4 # Display correlation matrix
#       5 print("Correlation Matrix:")
#
# NameError: name 'X_train' is not defined
